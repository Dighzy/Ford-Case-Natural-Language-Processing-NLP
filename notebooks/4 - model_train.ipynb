# %% [markdown]
# # Model Training

# %% [markdown]
# ## Setting Imports And Loading Data

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import ast
import matplotlib.pyplot as plt

import keras_tuner as kt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout, BatchNormalization, GaussianNoise
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer

import random 
random.seed(4)


df_final = pd.read_csv('../data/processed/df_final_model.csv')

# %%
df_final.head(2)
# Out:
#                                    processed_summary  \
# 0  contact owns 2021 ford f 350 contact received ...
# 1  ford knew issue back 2021 filed agency yet wai...
#
#                                    summary_embedding  \
# 0  [-0.5503813028335571, -0.2038578987121582, 0.2...
# 1  [-0.12588243186473846, 0.09368353337049484, 0....
#
#                                      model_embedding  word_count  char_count  \
# 0  [0.040037598460912704, -0.27900347113609314, -...          77         565
# 1  [0.040037598460912704, -0.27900347113609314, -...          80         518
#
#    sentiment  category_binary
# 0  -0.009091  [0, 1, 1, 0, 0]
# 1   0.091667  [1, 1, 0, 0, 0]

# %% [markdown]
# ## Creating Topic Features

# %%
# Generatinhg additional features using a topic modeling 
tfidf = TfidfVectorizer(max_features=5000)
tfidf_matrix = tfidf.fit_transform(df_final["processed_summary"])

#Model identifies two latent topics in the dataset.
topic_model = LatentDirichletAllocation(n_components=2, random_state=42)
topic_features = topic_model.fit_transform(tfidf_matrix)

topic_df = pd.DataFrame(topic_features, columns=[f"topic_{i+1}" for i in range(topic_features.shape[1])])
df_final = pd.concat([df_final, topic_df], axis=1)

# %%
import joblib
# Save the models
joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")
joblib.dump(topic_model, "../models/lda_model.pkl")
# Out:
# ['../models/lda_model.pkl']

# %%
# Checking some correlations
df_final.drop(['processed_summary', 'summary_embedding', 'model_embedding', 'category_binary'], axis=1).corr()
# Out:
#             word_count  char_count  sentiment   topic_1   topic_2
# word_count    1.000000    0.991726   0.051306  0.086088 -0.086088
# char_count    0.991726    1.000000   0.049456  0.012901 -0.012901
# sentiment     0.051306    0.049456   1.000000 -0.001529  0.001529
# topic_1       0.086088    0.012901  -0.001529  1.000000 -1.000000
# topic_2      -0.086088   -0.012901   0.001529 -1.000000  1.000000

# %% [markdown]
# ## Processing Features for Model Input

# %%
# Convert the object columns to a list
df_final["category_binary"] = df_final["category_binary"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df_final["model_embedding"] = df_final["model_embedding"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
df_final["summary_embedding"] = df_final["summary_embedding"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Convert embeddings and category binary column to NumPy arrays
X_embeddings = np.array(df_final["summary_embedding"].tolist())
y_category_binary = np.array(df_final["category_binary"].tolist())  # Ensure it's a 2D array
df_final['model_embedding'] = np.array(df_final["model_embedding"].tolist())

# Normalize additional features
additional_features = df_final[['model_embedding','word_count', 'char_count', 'sentiment', 'topic_1', 'topic_2']]
scaler = StandardScaler()
X_additional_features = scaler.fit_transform(additional_features)

# Split data into train and test sets
X_emb_train, X_emb_val, X_add_train, X_add_val, y_train, y_val = train_test_split(
    X_embeddings, X_additional_features, y_category_binary, test_size=0.2, random_state=42
)

# Take the first 10 rows from the validation set for the test set
X_emb_test = X_emb_val[:10]
X_add_test = X_add_val[:10]
y_test = y_val[:10]

# Remove those 10 rows from the validation set
X_emb_val = X_emb_val[10:]
X_add_val = X_add_val[10:]
y_val = y_val[10:]

# Verify the shapes of the data
print("X_emb_train shape:", X_emb_train.shape)  # Should match input shape for embedding input
print("X_add_train shape:", X_add_train.shape)  # Should match input shape for additional input
print("y_train shape:", y_train.shape)          # Should be (num_samples, 5) if 5 labels are expected
# Out:
# X_emb_train shape: (10806, 768)
# X_add_train shape: (10806, 6)
# y_train shape: (10806, 5)

# %%
import json
print("Scaler mean:", scaler.mean_)
print("Scaler scale:", scaler.scale_)

# Define mean and scale values
scaler_data = {
    "mean": scaler.mean_.tolist(),
    "scale": scaler.scale_.tolist()
}
# Save to JSON file
with open('../models/scaler_params.json', 'w') as f:
    json.dump(scaler_data, f)
# Out:
# Scaler mean: [2.11790538e-02 5.47353420e+01 3.81603568e+02 3.34108170e-03
#  6.30761131e-01 3.69238869e-01]
# Scaler scale: [1.65505123e-01 3.85491054e+01 2.65486573e+02 1.80745193e-01
#  3.42989438e-01 3.42989438e-01]

# %%
# Convert arrays to DataFrames
df_emb_test = pd.DataFrame(X_emb_test)
df_add_test = pd.DataFrame(X_add_test)

# Convert multi-label `y_test` into lists (each row is a list of labels)
y_test_lists = [list(row) for row in y_test]

# Combine features and labels into a single DataFrame
df_test_final = pd.DataFrame({
    'embeddings': df_emb_test.values.tolist(),  # Convert rows of feature data to  list
    'additional_features': df_add_test.values.tolist(),  # Convert additional features to list
    'category_binary': y_test_lists  # Store labels as lists
})

# Save to CSV
df_test_final.to_csv("../data/processed/test_data.csv", index=False)

# %% [markdown]
# ## Creating The Model

# %% [markdown]
# This model was chosen over others (BERT, RoBERTa) because it offers a simpler architecture that requires significantly less computational power.
#
# While transformer models can capture deeper semantic relationships, they are resource intensive.
#
# Our model effectively handles high-dimensional embeddings with a balance of complexity and performance, making it a practical choice for this task.

# %%
# The model uses two input branches: embeddings from complaint texts and structured features. 
# Gaussian noise and dropout improve generalization, while dense layers with batch normalization stabilize learning. 
# The dual-input approach enhances predictions by leveraging both semantic and contextual information. 
# Optimizations like learning rate scheduling, early stopping, and model checkpointing prevent overfitting.
# Additionally, Bayesian optimization was used to select the best hyperparameters, ensuring an efficient and effective search for optimal model configurations.


# Define the model-building function for the tuner
def build_model(hp):
    # Define inputs
    embedding_input = Input(shape=(X_emb_train.shape[1],), name="embedding_input")
    additional_input = Input(shape=(X_add_train.shape[1],), name="additional_input")

    # Add Gaussian noise as a regularization technique
    x1 = GaussianNoise(hp.Float('noise', 0.005, 0.02))(embedding_input)

    # Dense layer for embeddings (input from X_emb_train)
    x1 = Dense(hp.Int('units_x1', 64, 256, step=32), activation='relu', kernel_regularizer=l2(hp.Choice('l2_x1', [0.001, 0.01, 0.1])))(x1)
    x1 = BatchNormalization()(x1)
    x1 = Dropout(hp.Float('dropout_x1', 0.2, 0.5))(x1)

    # Dense layer for additional features (input from X_add_train)
    x2 = Dense(hp.Int('units_x2', 32, 128, step=16), activation='relu', kernel_regularizer=l2(hp.Choice('l2_x2', [0.001, 0.01, 0.1])))(additional_input)
    x2 = BatchNormalization()(x2)
    x2 = Dropout(hp.Float('dropout_x2', 0.2, 0.5))(x2)

    # Concatenate the two blocks of layers
    combined = Concatenate()([x1, x2])
    combined = Dense(hp.Int('units_combined', 16, 64, step=16), activation='relu', kernel_regularizer=l2(hp.Choice('l2_combined', [0.001, 0.01, 0.1])))(combined)
    combined = BatchNormalization()(combined)
    combined = Dropout(hp.Float('dropout_combined', 0.2, 0.5))(combined)

    # Output layer for multi-label classification (sigmoid activation for each label)
    output = Dense(5, activation='sigmoid')(combined)

    # Create the model
    model = Model(inputs=[embedding_input, additional_input], outputs=output)

    # Compile the model with Adam optimizer and binary cross-entropy loss for multi-label classification
    optimizer = Adam(learning_rate=hp.Float('learning_rate', 1e-5, 1e-3, sampling='log'))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', 'AUC', 'Recall', 'Precision'])

    return model

# Set up the tuner for Bayesian optimization
tuner = kt.BayesianOptimization(
    build_model,
    objective='val_loss',  # Optimize based on validation loss
    max_trials=20,  # Number of trials (different configurations)
    executions_per_trial=1,
    directory="../models/tuner_results", 
    project_name="bayesian_opt_nlp"  
)

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
best_model_path = "../models/best_model.h5"
model_checkpoint = ModelCheckpoint(filepath=best_model_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.25, patience=3, min_lr=1e-6)

# Start searching for the best hyperparameters
tuner.search(
    {"embedding_input": X_emb_train, "additional_input": X_add_train},
    y_train,
    validation_data=({"embedding_input": X_emb_val, "additional_input": X_add_val}, y_val),
    epochs=50,
    batch_size=128,
    callbacks=[early_stopping, model_checkpoint, lr_scheduler]
)

# Get the best hyperparameters from the search
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best hyperparameters found: {best_hps.values}")

# Train the final model using the best hyperparameters
model = tuner.hypermodel.build(best_hps)
history = model.fit(
    {"embedding_input": X_emb_train, "additional_input": X_add_train},
    y_train,
    validation_data=({"embedding_input": X_emb_val, "additional_input": X_add_val}, y_val),
    epochs=200,  
    batch_size=128,
    callbacks=[early_stopping, model_checkpoint, lr_scheduler]
)
# Out:
# Reloading Tuner from ../models/tuner_results\bayesian_opt_nlp\tuner0.json
# Best hyperparameters found: {'noise': 0.007875155616146979, 'units_x1': 256, 'l2_x1': 0.001, 'dropout_x1': 0.49870840952907197, 'units_x2': 48, 'l2_x2': 0.001, 'dropout_x2': 0.49462175893319893, 'units_combined': 64, 'l2_combined': 0.01, 'dropout_combined': 0.22088590109147924, 'learning_rate': 0.0008881172270305323}
# Epoch 1/200
# 81/85 [===========================>..] - ETA: 0s - loss: 1.7097 - accuracy: 0.4297 - auc: 0.7039 - recall: 0.6633 - precision: 0.3815
# Epoch 1: val_loss improved from inf to 1.27989, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 2s 14ms/step - loss: 1.6916 - accuracy: 0.4352 - auc: 0.7080 - recall: 0.6651 - precision: 0.3846 - val_loss: 1.2799 - val_accuracy: 0.4733 - val_auc: 0.7616 - val_recall: 0.5030 - val_precision: 0.5964 - lr: 8.8812e-04
# Epoch 2/200
# 85/85 [==============================] - ETA: 0s - loss: 0.9939 - accuracy: 0.6095 - auc: 0.8436 - recall: 0.7217 - precision: 0.5522
# Epoch 2: val_loss improved from 1.27989 to 0.87660, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.9939 - accuracy: 0.6095 - auc: 0.8436 - recall: 0.7217 - precision: 0.5522 - val_loss: 0.8766 - val_accuracy: 0.5074 - val_auc: 0.8227 - val_recall: 0.1989 - val_precision: 0.8367 - lr: 8.8812e-04
# Epoch 3/200
# 85/85 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.6644 - auc: 0.8873 - recall: 0.6949 - precision: 0.6855
# Epoch 3: val_loss improved from 0.87660 to 0.74614, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.6869 - accuracy: 0.6644 - auc: 0.8873 - recall: 0.6949 - precision: 0.6855 - val_loss: 0.7461 - val_accuracy: 0.3629 - val_auc: 0.7546 - val_recall: 0.1829 - val_precision: 0.7604 - lr: 8.8812e-04
# Epoch 4/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7019 - auc: 0.9093 - recall: 0.6863 - precision: 0.7572
# Epoch 4: val_loss improved from 0.74614 to 0.59291, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.5422 - accuracy: 0.7020 - auc: 0.9093 - recall: 0.6863 - precision: 0.7576 - val_loss: 0.5929 - val_accuracy: 0.6649 - val_auc: 0.9111 - val_recall: 0.2248 - val_precision: 0.9681 - lr: 8.8812e-04
# Epoch 5/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.4675 - accuracy: 0.7189 - auc: 0.9228 - recall: 0.6947 - precision: 0.7914
# Epoch 5: val_loss improved from 0.59291 to 0.48886, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.4671 - accuracy: 0.7190 - auc: 0.9228 - recall: 0.6945 - precision: 0.7918 - val_loss: 0.4889 - val_accuracy: 0.6846 - val_auc: 0.9251 - val_recall: 0.4839 - val_precision: 0.9158 - lr: 8.8812e-04
# Epoch 6/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.4205 - accuracy: 0.7349 - auc: 0.9322 - recall: 0.7101 - precision: 0.8168
# Epoch 6: val_loss improved from 0.48886 to 0.47901, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.4195 - accuracy: 0.7354 - auc: 0.9323 - recall: 0.7109 - precision: 0.8172 - val_loss: 0.4790 - val_accuracy: 0.6025 - val_auc: 0.8963 - val_recall: 0.4942 - val_precision: 0.8400 - lr: 8.8812e-04
# Epoch 7/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.3922 - accuracy: 0.7342 - auc: 0.9364 - recall: 0.7156 - precision: 0.8259
# Epoch 7: val_loss improved from 0.47901 to 0.41770, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.3917 - accuracy: 0.7337 - auc: 0.9366 - recall: 0.7154 - precision: 0.8257 - val_loss: 0.4177 - val_accuracy: 0.6519 - val_auc: 0.9330 - val_recall: 0.6516 - val_precision: 0.8216 - lr: 8.8812e-04
# Epoch 8/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.3720 - accuracy: 0.7433 - auc: 0.9402 - recall: 0.7225 - precision: 0.8317
# Epoch 8: val_loss did not improve from 0.41770
# 85/85 [==============================] - 1s 10ms/step - loss: 0.3720 - accuracy: 0.7436 - auc: 0.9402 - recall: 0.7226 - precision: 0.8317 - val_loss: 0.4664 - val_accuracy: 0.6393 - val_auc: 0.8852 - val_recall: 0.6031 - val_precision: 0.7564 - lr: 8.8812e-04
# Epoch 9/200
# 85/85 [==============================] - ETA: 0s - loss: 0.3556 - accuracy: 0.7526 - auc: 0.9426 - recall: 0.7359 - precision: 0.8348
# Epoch 9: val_loss improved from 0.41770 to 0.40638, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.3556 - accuracy: 0.7526 - auc: 0.9426 - recall: 0.7359 - precision: 0.8348 - val_loss: 0.4064 - val_accuracy: 0.6987 - val_auc: 0.9153 - val_recall: 0.6200 - val_precision: 0.8429 - lr: 8.8812e-04
# Epoch 10/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.3447 - accuracy: 0.7573 - auc: 0.9455 - recall: 0.7438 - precision: 0.8414
# Epoch 10: val_loss improved from 0.40638 to 0.33566, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.3448 - accuracy: 0.7582 - auc: 0.9454 - recall: 0.7442 - precision: 0.8414 - val_loss: 0.3357 - val_accuracy: 0.7831 - val_auc: 0.9507 - val_recall: 0.7698 - val_precision: 0.8426 - lr: 8.8812e-04
# Epoch 11/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.3302 - accuracy: 0.7590 - auc: 0.9500 - recall: 0.7573 - precision: 0.8496
# Epoch 11: val_loss did not improve from 0.33566
# 85/85 [==============================] - 1s 9ms/step - loss: 0.3309 - accuracy: 0.7587 - auc: 0.9495 - recall: 0.7566 - precision: 0.8491 - val_loss: 0.4222 - val_accuracy: 0.6828 - val_auc: 0.9074 - val_recall: 0.5900 - val_precision: 0.7988 - lr: 8.8812e-04
# Epoch 12/200
# 85/85 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.7544 - auc: 0.9494 - recall: 0.7539 - precision: 0.8456
# Epoch 12: val_loss did not improve from 0.33566
# 85/85 [==============================] - 1s 9ms/step - loss: 0.3266 - accuracy: 0.7544 - auc: 0.9494 - recall: 0.7539 - precision: 0.8456 - val_loss: 0.4002 - val_accuracy: 0.6906 - val_auc: 0.9194 - val_recall: 0.6619 - val_precision: 0.7741 - lr: 8.8812e-04
# Epoch 13/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.3163 - accuracy: 0.7649 - auc: 0.9522 - recall: 0.7623 - precision: 0.8519
# Epoch 13: val_loss did not improve from 0.33566
# 85/85 [==============================] - 1s 9ms/step - loss: 0.3162 - accuracy: 0.7648 - auc: 0.9523 - recall: 0.7620 - precision: 0.8518 - val_loss: 0.3392 - val_accuracy: 0.7704 - val_auc: 0.9469 - val_recall: 0.6576 - val_precision: 0.8931 - lr: 8.8812e-04
# Epoch 14/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.2835 - accuracy: 0.7872 - auc: 0.9642 - recall: 0.7966 - precision: 0.8794
# Epoch 14: val_loss improved from 0.33566 to 0.28353, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2833 - accuracy: 0.7872 - auc: 0.9643 - recall: 0.7969 - precision: 0.8794 - val_loss: 0.2835 - val_accuracy: 0.7957 - val_auc: 0.9688 - val_recall: 0.7663 - val_precision: 0.9158 - lr: 2.2203e-04
# Epoch 15/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.2662 - accuracy: 0.7952 - auc: 0.9689 - recall: 0.8131 - precision: 0.8913
# Epoch 15: val_loss improved from 0.28353 to 0.27040, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2661 - accuracy: 0.7956 - auc: 0.9689 - recall: 0.8134 - precision: 0.8909 - val_loss: 0.2704 - val_accuracy: 0.8027 - val_auc: 0.9777 - val_recall: 0.7729 - val_precision: 0.9472 - lr: 2.2203e-04
# Epoch 16/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.2532 - accuracy: 0.7999 - auc: 0.9726 - recall: 0.8251 - precision: 0.8969
# Epoch 16: val_loss improved from 0.27040 to 0.26396, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2539 - accuracy: 0.7998 - auc: 0.9723 - recall: 0.8244 - precision: 0.8967 - val_loss: 0.2640 - val_accuracy: 0.7723 - val_auc: 0.9756 - val_recall: 0.7786 - val_precision: 0.9362 - lr: 2.2203e-04
# Epoch 17/200
# 85/85 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.8108 - auc: 0.9741 - recall: 0.8335 - precision: 0.9047
# Epoch 17: val_loss improved from 0.26396 to 0.25111, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.2439 - accuracy: 0.8108 - auc: 0.9741 - recall: 0.8335 - precision: 0.9047 - val_loss: 0.2511 - val_accuracy: 0.8109 - val_auc: 0.9731 - val_recall: 0.7937 - val_precision: 0.9163 - lr: 2.2203e-04
# Epoch 18/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.2381 - accuracy: 0.8054 - auc: 0.9752 - recall: 0.8364 - precision: 0.8996
# Epoch 18: val_loss improved from 0.25111 to 0.22742, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2379 - accuracy: 0.8059 - auc: 0.9753 - recall: 0.8369 - precision: 0.9000 - val_loss: 0.2274 - val_accuracy: 0.8020 - val_auc: 0.9809 - val_recall: 0.8359 - val_precision: 0.9361 - lr: 2.2203e-04
# Epoch 19/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.2329 - accuracy: 0.8126 - auc: 0.9759 - recall: 0.8420 - precision: 0.9049
# Epoch 19: val_loss improved from 0.22742 to 0.22485, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2330 - accuracy: 0.8135 - auc: 0.9759 - recall: 0.8425 - precision: 0.9062 - val_loss: 0.2248 - val_accuracy: 0.8247 - val_auc: 0.9821 - val_recall: 0.8211 - val_precision: 0.9552 - lr: 2.2203e-04
# Epoch 20/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.2249 - accuracy: 0.8147 - auc: 0.9774 - recall: 0.8435 - precision: 0.9098
# Epoch 20: val_loss did not improve from 0.22485
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2245 - accuracy: 0.8151 - auc: 0.9776 - recall: 0.8440 - precision: 0.9105 - val_loss: 0.2257 - val_accuracy: 0.8158 - val_auc: 0.9815 - val_recall: 0.8371 - val_precision: 0.9480 - lr: 2.2203e-04
# Epoch 21/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.2198 - accuracy: 0.8181 - auc: 0.9782 - recall: 0.8505 - precision: 0.9097
# Epoch 21: val_loss improved from 0.22485 to 0.21746, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2203 - accuracy: 0.8188 - auc: 0.9781 - recall: 0.8497 - precision: 0.9090 - val_loss: 0.2175 - val_accuracy: 0.8120 - val_auc: 0.9826 - val_recall: 0.8054 - val_precision: 0.9641 - lr: 2.2203e-04
# Epoch 22/200
# 85/85 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.8210 - auc: 0.9790 - recall: 0.8550 - precision: 0.9105
# Epoch 22: val_loss improved from 0.21746 to 0.21609, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2156 - accuracy: 0.8210 - auc: 0.9790 - recall: 0.8550 - precision: 0.9105 - val_loss: 0.2161 - val_accuracy: 0.8076 - val_auc: 0.9816 - val_recall: 0.8354 - val_precision: 0.9269 - lr: 2.2203e-04
# Epoch 23/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.2139 - accuracy: 0.8145 - auc: 0.9790 - recall: 0.8547 - precision: 0.9088
# Epoch 23: val_loss improved from 0.21609 to 0.19333, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2139 - accuracy: 0.8146 - auc: 0.9790 - recall: 0.8544 - precision: 0.9089 - val_loss: 0.1933 - val_accuracy: 0.8265 - val_auc: 0.9851 - val_recall: 0.8476 - val_precision: 0.9544 - lr: 2.2203e-04
# Epoch 24/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.2062 - accuracy: 0.8196 - auc: 0.9808 - recall: 0.8580 - precision: 0.9192
# Epoch 24: val_loss did not improve from 0.19333
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2063 - accuracy: 0.8200 - auc: 0.9807 - recall: 0.8582 - precision: 0.9191 - val_loss: 0.2127 - val_accuracy: 0.7686 - val_auc: 0.9811 - val_recall: 0.8468 - val_precision: 0.9336 - lr: 2.2203e-04
# Epoch 25/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.2060 - accuracy: 0.8218 - auc: 0.9801 - recall: 0.8614 - precision: 0.9134
# Epoch 25: val_loss did not improve from 0.19333
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2062 - accuracy: 0.8218 - auc: 0.9800 - recall: 0.8613 - precision: 0.9128 - val_loss: 0.1961 - val_accuracy: 0.8020 - val_auc: 0.9838 - val_recall: 0.8459 - val_precision: 0.9500 - lr: 2.2203e-04
# Epoch 26/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1975 - accuracy: 0.8193 - auc: 0.9823 - recall: 0.8629 - precision: 0.9200
# Epoch 26: val_loss did not improve from 0.19333
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1985 - accuracy: 0.8183 - auc: 0.9821 - recall: 0.8613 - precision: 0.9197 - val_loss: 0.2002 - val_accuracy: 0.7834 - val_auc: 0.9815 - val_recall: 0.8756 - val_precision: 0.9225 - lr: 2.2203e-04
# Epoch 27/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1909 - accuracy: 0.8256 - auc: 0.9838 - recall: 0.8716 - precision: 0.9214
# Epoch 27: val_loss improved from 0.19333 to 0.17271, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1908 - accuracy: 0.8257 - auc: 0.9838 - recall: 0.8719 - precision: 0.9217 - val_loss: 0.1727 - val_accuracy: 0.8236 - val_auc: 0.9880 - val_recall: 0.8870 - val_precision: 0.9525 - lr: 5.5507e-05
# Epoch 28/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1849 - accuracy: 0.8296 - auc: 0.9849 - recall: 0.8794 - precision: 0.9269
# Epoch 28: val_loss improved from 0.17271 to 0.16885, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1846 - accuracy: 0.8294 - auc: 0.9850 - recall: 0.8793 - precision: 0.9267 - val_loss: 0.1689 - val_accuracy: 0.8358 - val_auc: 0.9889 - val_recall: 0.8850 - val_precision: 0.9598 - lr: 5.5507e-05
# Epoch 29/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1801 - accuracy: 0.8345 - auc: 0.9859 - recall: 0.8850 - precision: 0.9333
# Epoch 29: val_loss improved from 0.16885 to 0.16850, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1801 - accuracy: 0.8345 - auc: 0.9859 - recall: 0.8850 - precision: 0.9333 - val_loss: 0.1685 - val_accuracy: 0.8295 - val_auc: 0.9886 - val_recall: 0.8919 - val_precision: 0.9536 - lr: 5.5507e-05
# Epoch 30/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1811 - accuracy: 0.8281 - auc: 0.9856 - recall: 0.8844 - precision: 0.9282
# Epoch 30: val_loss improved from 0.16850 to 0.16444, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1813 - accuracy: 0.8285 - auc: 0.9856 - recall: 0.8845 - precision: 0.9281 - val_loss: 0.1644 - val_accuracy: 0.8306 - val_auc: 0.9891 - val_recall: 0.8927 - val_precision: 0.9548 - lr: 5.5507e-05
# Epoch 31/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.8337 - auc: 0.9868 - recall: 0.8877 - precision: 0.9322
# Epoch 31: val_loss did not improve from 0.16444
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1762 - accuracy: 0.8337 - auc: 0.9868 - recall: 0.8877 - precision: 0.9322 - val_loss: 0.1664 - val_accuracy: 0.8458 - val_auc: 0.9887 - val_recall: 0.8864 - val_precision: 0.9539 - lr: 5.5507e-05
# Epoch 32/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.8326 - auc: 0.9860 - recall: 0.8839 - precision: 0.9315
# Epoch 32: val_loss improved from 0.16444 to 0.16111, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1776 - accuracy: 0.8326 - auc: 0.9860 - recall: 0.8839 - precision: 0.9315 - val_loss: 0.1611 - val_accuracy: 0.8358 - val_auc: 0.9893 - val_recall: 0.8973 - val_precision: 0.9513 - lr: 5.5507e-05
# Epoch 33/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1719 - accuracy: 0.8363 - auc: 0.9873 - recall: 0.8903 - precision: 0.9373
# Epoch 33: val_loss improved from 0.16111 to 0.16006, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1719 - accuracy: 0.8365 - auc: 0.9873 - recall: 0.8901 - precision: 0.9373 - val_loss: 0.1601 - val_accuracy: 0.8224 - val_auc: 0.9897 - val_recall: 0.8922 - val_precision: 0.9604 - lr: 5.5507e-05
# Epoch 34/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1725 - accuracy: 0.8352 - auc: 0.9871 - recall: 0.8885 - precision: 0.9334
# Epoch 34: val_loss did not improve from 0.16006
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1726 - accuracy: 0.8349 - auc: 0.9870 - recall: 0.8886 - precision: 0.9331 - val_loss: 0.1618 - val_accuracy: 0.8310 - val_auc: 0.9890 - val_recall: 0.8882 - val_precision: 0.9561 - lr: 5.5507e-05
# Epoch 35/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1693 - accuracy: 0.8350 - auc: 0.9877 - recall: 0.8933 - precision: 0.9358
# Epoch 35: val_loss improved from 0.16006 to 0.15559, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1691 - accuracy: 0.8357 - auc: 0.9878 - recall: 0.8934 - precision: 0.9361 - val_loss: 0.1556 - val_accuracy: 0.8262 - val_auc: 0.9899 - val_recall: 0.9001 - val_precision: 0.9572 - lr: 5.5507e-05
# Epoch 36/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1698 - accuracy: 0.8318 - auc: 0.9873 - recall: 0.8898 - precision: 0.9320
# Epoch 36: val_loss did not improve from 0.15559
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1697 - accuracy: 0.8319 - auc: 0.9874 - recall: 0.8897 - precision: 0.9322 - val_loss: 0.1556 - val_accuracy: 0.8470 - val_auc: 0.9894 - val_recall: 0.9078 - val_precision: 0.9513 - lr: 5.5507e-05
# Epoch 37/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1662 - accuracy: 0.8393 - auc: 0.9884 - recall: 0.8922 - precision: 0.9366
# Epoch 37: val_loss did not improve from 0.15559
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1662 - accuracy: 0.8393 - auc: 0.9884 - recall: 0.8923 - precision: 0.9364 - val_loss: 0.1566 - val_accuracy: 0.8366 - val_auc: 0.9895 - val_recall: 0.9016 - val_precision: 0.9544 - lr: 5.5507e-05
# Epoch 38/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.8401 - auc: 0.9883 - recall: 0.8963 - precision: 0.9384
# Epoch 38: val_loss did not improve from 0.15559
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1650 - accuracy: 0.8398 - auc: 0.9883 - recall: 0.8959 - precision: 0.9385 - val_loss: 0.1560 - val_accuracy: 0.8262 - val_auc: 0.9893 - val_recall: 0.9001 - val_precision: 0.9537 - lr: 5.5507e-05
# Epoch 39/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.8399 - auc: 0.9881 - recall: 0.8948 - precision: 0.9366
# Epoch 39: val_loss improved from 0.15559 to 0.15029, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1648 - accuracy: 0.8399 - auc: 0.9881 - recall: 0.8951 - precision: 0.9366 - val_loss: 0.1503 - val_accuracy: 0.8288 - val_auc: 0.9904 - val_recall: 0.9033 - val_precision: 0.9577 - lr: 1.3877e-05
# Epoch 40/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.8397 - auc: 0.9892 - recall: 0.8984 - precision: 0.9390
# Epoch 40: val_loss improved from 0.15029 to 0.14954, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1611 - accuracy: 0.8397 - auc: 0.9892 - recall: 0.8984 - precision: 0.9390 - val_loss: 0.1495 - val_accuracy: 0.8302 - val_auc: 0.9906 - val_recall: 0.9039 - val_precision: 0.9591 - lr: 1.3877e-05
# Epoch 41/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1618 - accuracy: 0.8362 - auc: 0.9889 - recall: 0.8997 - precision: 0.9385
# Epoch 41: val_loss improved from 0.14954 to 0.14876, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 9ms/step - loss: 0.1618 - accuracy: 0.8359 - auc: 0.9889 - recall: 0.8994 - precision: 0.9388 - val_loss: 0.1488 - val_accuracy: 0.8284 - val_auc: 0.9908 - val_recall: 0.9024 - val_precision: 0.9594 - lr: 1.3877e-05
# Epoch 42/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1603 - accuracy: 0.8396 - auc: 0.9893 - recall: 0.8989 - precision: 0.9429
# Epoch 42: val_loss improved from 0.14876 to 0.14812, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1602 - accuracy: 0.8404 - auc: 0.9893 - recall: 0.8991 - precision: 0.9428 - val_loss: 0.1481 - val_accuracy: 0.8325 - val_auc: 0.9908 - val_recall: 0.9030 - val_precision: 0.9571 - lr: 1.3877e-05
# Epoch 43/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.8386 - auc: 0.9892 - recall: 0.8987 - precision: 0.9383
# Epoch 43: val_loss did not improve from 0.14812
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1603 - accuracy: 0.8386 - auc: 0.9892 - recall: 0.8987 - precision: 0.9383 - val_loss: 0.1486 - val_accuracy: 0.8317 - val_auc: 0.9906 - val_recall: 0.9070 - val_precision: 0.9590 - lr: 1.3877e-05
# Epoch 44/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1604 - accuracy: 0.8389 - auc: 0.9890 - recall: 0.9011 - precision: 0.9370
# Epoch 44: val_loss improved from 0.14812 to 0.14691, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1603 - accuracy: 0.8395 - auc: 0.9890 - recall: 0.9016 - precision: 0.9375 - val_loss: 0.1469 - val_accuracy: 0.8314 - val_auc: 0.9908 - val_recall: 0.9093 - val_precision: 0.9565 - lr: 1.3877e-05
# Epoch 45/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1580 - accuracy: 0.8376 - auc: 0.9897 - recall: 0.9045 - precision: 0.9414
# Epoch 45: val_loss improved from 0.14691 to 0.14655, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1583 - accuracy: 0.8370 - auc: 0.9896 - recall: 0.9045 - precision: 0.9412 - val_loss: 0.1465 - val_accuracy: 0.8336 - val_auc: 0.9909 - val_recall: 0.9067 - val_precision: 0.9569 - lr: 1.3877e-05
# Epoch 46/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.8389 - auc: 0.9897 - recall: 0.9007 - precision: 0.9406
# Epoch 46: val_loss did not improve from 0.14655
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1581 - accuracy: 0.8389 - auc: 0.9897 - recall: 0.9007 - precision: 0.9406 - val_loss: 0.1469 - val_accuracy: 0.8262 - val_auc: 0.9910 - val_recall: 0.9027 - val_precision: 0.9602 - lr: 1.3877e-05
# Epoch 47/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.8428 - auc: 0.9898 - recall: 0.9018 - precision: 0.9414
# Epoch 47: val_loss improved from 0.14655 to 0.14588, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1568 - accuracy: 0.8428 - auc: 0.9898 - recall: 0.9018 - precision: 0.9414 - val_loss: 0.1459 - val_accuracy: 0.8343 - val_auc: 0.9911 - val_recall: 0.9067 - val_precision: 0.9584 - lr: 1.3877e-05
# Epoch 48/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1584 - accuracy: 0.8394 - auc: 0.9893 - recall: 0.9008 - precision: 0.9419
# Epoch 48: val_loss improved from 0.14588 to 0.14543, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1584 - accuracy: 0.8417 - auc: 0.9894 - recall: 0.9014 - precision: 0.9408 - val_loss: 0.1454 - val_accuracy: 0.8302 - val_auc: 0.9911 - val_recall: 0.9073 - val_precision: 0.9561 - lr: 1.3877e-05
# Epoch 49/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.8381 - auc: 0.9892 - recall: 0.8989 - precision: 0.9399
# Epoch 49: val_loss did not improve from 0.14543
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1591 - accuracy: 0.8381 - auc: 0.9892 - recall: 0.8989 - precision: 0.9399 - val_loss: 0.1455 - val_accuracy: 0.8362 - val_auc: 0.9911 - val_recall: 0.9070 - val_precision: 0.9584 - lr: 1.3877e-05
# Epoch 50/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1578 - accuracy: 0.8435 - auc: 0.9894 - recall: 0.8982 - precision: 0.9421
# Epoch 50: val_loss improved from 0.14543 to 0.14491, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1580 - accuracy: 0.8429 - auc: 0.9893 - recall: 0.8983 - precision: 0.9414 - val_loss: 0.1449 - val_accuracy: 0.8351 - val_auc: 0.9911 - val_recall: 0.9076 - val_precision: 0.9570 - lr: 1.3877e-05
# Epoch 51/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1553 - accuracy: 0.8393 - auc: 0.9901 - recall: 0.9015 - precision: 0.9416
# Epoch 51: val_loss improved from 0.14491 to 0.14476, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1552 - accuracy: 0.8390 - auc: 0.9901 - recall: 0.9016 - precision: 0.9418 - val_loss: 0.1448 - val_accuracy: 0.8369 - val_auc: 0.9909 - val_recall: 0.9087 - val_precision: 0.9553 - lr: 1.3877e-05
# Epoch 52/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.8415 - auc: 0.9901 - recall: 0.9021 - precision: 0.9476
# Epoch 52: val_loss improved from 0.14476 to 0.14399, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1545 - accuracy: 0.8415 - auc: 0.9901 - recall: 0.9021 - precision: 0.9476 - val_loss: 0.1440 - val_accuracy: 0.8340 - val_auc: 0.9912 - val_recall: 0.9064 - val_precision: 0.9592 - lr: 1.3877e-05
# Epoch 53/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1561 - accuracy: 0.8364 - auc: 0.9898 - recall: 0.9019 - precision: 0.9408
# Epoch 53: val_loss did not improve from 0.14399
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1560 - accuracy: 0.8368 - auc: 0.9898 - recall: 0.9021 - precision: 0.9407 - val_loss: 0.1446 - val_accuracy: 0.8336 - val_auc: 0.9911 - val_recall: 0.9078 - val_precision: 0.9584 - lr: 1.3877e-05
# Epoch 54/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1554 - accuracy: 0.8393 - auc: 0.9898 - recall: 0.9031 - precision: 0.9407
# Epoch 54: val_loss did not improve from 0.14399
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1554 - accuracy: 0.8393 - auc: 0.9898 - recall: 0.9031 - precision: 0.9407 - val_loss: 0.1442 - val_accuracy: 0.8351 - val_auc: 0.9912 - val_recall: 0.9044 - val_precision: 0.9580 - lr: 1.3877e-05
# Epoch 55/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1537 - accuracy: 0.8421 - auc: 0.9902 - recall: 0.9066 - precision: 0.9421
# Epoch 55: val_loss improved from 0.14399 to 0.14373, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1537 - accuracy: 0.8418 - auc: 0.9902 - recall: 0.9060 - precision: 0.9423 - val_loss: 0.1437 - val_accuracy: 0.8377 - val_auc: 0.9912 - val_recall: 0.9073 - val_precision: 0.9567 - lr: 1.3877e-05
# Epoch 56/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1548 - accuracy: 0.8389 - auc: 0.9900 - recall: 0.9046 - precision: 0.9410
# Epoch 56: val_loss improved from 0.14373 to 0.14361, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1547 - accuracy: 0.8391 - auc: 0.9900 - recall: 0.9047 - precision: 0.9411 - val_loss: 0.1436 - val_accuracy: 0.8343 - val_auc: 0.9910 - val_recall: 0.9101 - val_precision: 0.9568 - lr: 1.3877e-05
# Epoch 57/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1530 - accuracy: 0.8449 - auc: 0.9901 - recall: 0.9066 - precision: 0.9424
# Epoch 57: val_loss improved from 0.14361 to 0.14242, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1532 - accuracy: 0.8447 - auc: 0.9900 - recall: 0.9065 - precision: 0.9419 - val_loss: 0.1424 - val_accuracy: 0.8347 - val_auc: 0.9911 - val_recall: 0.9107 - val_precision: 0.9574 - lr: 1.3877e-05
# Epoch 58/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1523 - accuracy: 0.8463 - auc: 0.9905 - recall: 0.9050 - precision: 0.9442
# Epoch 58: val_loss did not improve from 0.14242
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1523 - accuracy: 0.8461 - auc: 0.9904 - recall: 0.9052 - precision: 0.9442 - val_loss: 0.1429 - val_accuracy: 0.8332 - val_auc: 0.9912 - val_recall: 0.9093 - val_precision: 0.9582 - lr: 1.3877e-05
# Epoch 59/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.8370 - auc: 0.9900 - recall: 0.9016 - precision: 0.9412
# Epoch 59: val_loss improved from 0.14242 to 0.14206, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1543 - accuracy: 0.8370 - auc: 0.9900 - recall: 0.9016 - precision: 0.9412 - val_loss: 0.1421 - val_accuracy: 0.8369 - val_auc: 0.9913 - val_recall: 0.9090 - val_precision: 0.9596 - lr: 1.3877e-05
# Epoch 60/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.8459 - auc: 0.9900 - recall: 0.9043 - precision: 0.9419
# Epoch 60: val_loss improved from 0.14206 to 0.14167, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1525 - accuracy: 0.8459 - auc: 0.9900 - recall: 0.9043 - precision: 0.9419 - val_loss: 0.1417 - val_accuracy: 0.8369 - val_auc: 0.9915 - val_recall: 0.9084 - val_precision: 0.9593 - lr: 1.3877e-05
# Epoch 61/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1540 - accuracy: 0.8405 - auc: 0.9899 - recall: 0.9011 - precision: 0.9418
# Epoch 61: val_loss improved from 0.14167 to 0.14079, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1538 - accuracy: 0.8412 - auc: 0.9900 - recall: 0.9012 - precision: 0.9416 - val_loss: 0.1408 - val_accuracy: 0.8358 - val_auc: 0.9914 - val_recall: 0.9067 - val_precision: 0.9601 - lr: 1.3877e-05
# Epoch 62/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1539 - accuracy: 0.8403 - auc: 0.9899 - recall: 0.9014 - precision: 0.9398
# Epoch 62: val_loss did not improve from 0.14079
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1537 - accuracy: 0.8408 - auc: 0.9899 - recall: 0.9015 - precision: 0.9404 - val_loss: 0.1408 - val_accuracy: 0.8392 - val_auc: 0.9914 - val_recall: 0.9078 - val_precision: 0.9570 - lr: 1.3877e-05
# Epoch 63/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.8443 - auc: 0.9901 - recall: 0.9042 - precision: 0.9430
# Epoch 63: val_loss improved from 0.14079 to 0.14020, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1528 - accuracy: 0.8443 - auc: 0.9901 - recall: 0.9042 - precision: 0.9430 - val_loss: 0.1402 - val_accuracy: 0.8351 - val_auc: 0.9916 - val_recall: 0.9064 - val_precision: 0.9595 - lr: 1.3877e-05
# Epoch 64/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1504 - accuracy: 0.8380 - auc: 0.9906 - recall: 0.9061 - precision: 0.9450
# Epoch 64: val_loss improved from 0.14020 to 0.13951, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1509 - accuracy: 0.8376 - auc: 0.9905 - recall: 0.9050 - precision: 0.9455 - val_loss: 0.1395 - val_accuracy: 0.8354 - val_auc: 0.9915 - val_recall: 0.9067 - val_precision: 0.9601 - lr: 1.3877e-05
# Epoch 65/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1505 - accuracy: 0.8427 - auc: 0.9905 - recall: 0.9055 - precision: 0.9463
# Epoch 65: val_loss improved from 0.13951 to 0.13919, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1509 - accuracy: 0.8418 - auc: 0.9904 - recall: 0.9047 - precision: 0.9459 - val_loss: 0.1392 - val_accuracy: 0.8380 - val_auc: 0.9914 - val_recall: 0.9096 - val_precision: 0.9574 - lr: 1.3877e-05
# Epoch 66/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1513 - accuracy: 0.8383 - auc: 0.9904 - recall: 0.9072 - precision: 0.9413
# Epoch 66: val_loss did not improve from 0.13919
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1508 - accuracy: 0.8381 - auc: 0.9904 - recall: 0.9076 - precision: 0.9417 - val_loss: 0.1392 - val_accuracy: 0.8369 - val_auc: 0.9914 - val_recall: 0.9098 - val_precision: 0.9597 - lr: 1.3877e-05
# Epoch 67/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1497 - accuracy: 0.8460 - auc: 0.9906 - recall: 0.9035 - precision: 0.9460
# Epoch 67: val_loss improved from 0.13919 to 0.13908, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1494 - accuracy: 0.8467 - auc: 0.9907 - recall: 0.9037 - precision: 0.9464 - val_loss: 0.1391 - val_accuracy: 0.8347 - val_auc: 0.9914 - val_recall: 0.9098 - val_precision: 0.9585 - lr: 1.3877e-05
# Epoch 68/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1482 - accuracy: 0.8436 - auc: 0.9911 - recall: 0.9071 - precision: 0.9429
# Epoch 68: val_loss did not improve from 0.13908
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1481 - accuracy: 0.8432 - auc: 0.9911 - recall: 0.9071 - precision: 0.9430 - val_loss: 0.1405 - val_accuracy: 0.8328 - val_auc: 0.9913 - val_recall: 0.9056 - val_precision: 0.9586 - lr: 1.3877e-05
# Epoch 69/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1492 - accuracy: 0.8415 - auc: 0.9908 - recall: 0.9074 - precision: 0.9436
# Epoch 69: val_loss improved from 0.13908 to 0.13828, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1492 - accuracy: 0.8415 - auc: 0.9908 - recall: 0.9073 - precision: 0.9434 - val_loss: 0.1383 - val_accuracy: 0.8369 - val_auc: 0.9917 - val_recall: 0.9121 - val_precision: 0.9595 - lr: 1.3877e-05
# Epoch 70/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.8442 - auc: 0.9913 - recall: 0.9064 - precision: 0.9417
# Epoch 70: val_loss improved from 0.13828 to 0.13799, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1475 - accuracy: 0.8442 - auc: 0.9913 - recall: 0.9064 - precision: 0.9417 - val_loss: 0.1380 - val_accuracy: 0.8336 - val_auc: 0.9917 - val_recall: 0.9116 - val_precision: 0.9589 - lr: 1.3877e-05
# Epoch 71/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1474 - accuracy: 0.8438 - auc: 0.9911 - recall: 0.9059 - precision: 0.9466
# Epoch 71: val_loss did not improve from 0.13799
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1472 - accuracy: 0.8443 - auc: 0.9911 - recall: 0.9062 - precision: 0.9466 - val_loss: 0.1382 - val_accuracy: 0.8366 - val_auc: 0.9917 - val_recall: 0.9098 - val_precision: 0.9579 - lr: 1.3877e-05
# Epoch 72/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1453 - accuracy: 0.8458 - auc: 0.9913 - recall: 0.9099 - precision: 0.9461
# Epoch 72: val_loss improved from 0.13799 to 0.13754, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1448 - accuracy: 0.8468 - auc: 0.9914 - recall: 0.9104 - precision: 0.9465 - val_loss: 0.1375 - val_accuracy: 0.8347 - val_auc: 0.9916 - val_recall: 0.9101 - val_precision: 0.9591 - lr: 1.3877e-05
# Epoch 73/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1478 - accuracy: 0.8376 - auc: 0.9907 - recall: 0.9049 - precision: 0.9482
# Epoch 73: val_loss improved from 0.13754 to 0.13720, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1474 - accuracy: 0.8379 - auc: 0.9908 - recall: 0.9053 - precision: 0.9479 - val_loss: 0.1372 - val_accuracy: 0.8358 - val_auc: 0.9916 - val_recall: 0.9101 - val_precision: 0.9600 - lr: 1.3877e-05
# Epoch 74/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1460 - accuracy: 0.8437 - auc: 0.9912 - recall: 0.9061 - precision: 0.9479
# Epoch 74: val_loss improved from 0.13720 to 0.13693, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1469 - accuracy: 0.8420 - auc: 0.9910 - recall: 0.9052 - precision: 0.9473 - val_loss: 0.1369 - val_accuracy: 0.8362 - val_auc: 0.9917 - val_recall: 0.9096 - val_precision: 0.9585 - lr: 1.3877e-05
# Epoch 75/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1445 - accuracy: 0.8462 - auc: 0.9915 - recall: 0.9106 - precision: 0.9475
# Epoch 75: val_loss improved from 0.13693 to 0.13654, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1446 - accuracy: 0.8468 - auc: 0.9915 - recall: 0.9103 - precision: 0.9475 - val_loss: 0.1365 - val_accuracy: 0.8399 - val_auc: 0.9918 - val_recall: 0.9081 - val_precision: 0.9587 - lr: 1.3877e-05
# Epoch 76/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1482 - accuracy: 0.8391 - auc: 0.9906 - recall: 0.9054 - precision: 0.9469
# Epoch 76: val_loss improved from 0.13654 to 0.13615, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1475 - accuracy: 0.8398 - auc: 0.9907 - recall: 0.9060 - precision: 0.9475 - val_loss: 0.1362 - val_accuracy: 0.8399 - val_auc: 0.9918 - val_recall: 0.9121 - val_precision: 0.9563 - lr: 1.3877e-05
# Epoch 77/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1446 - accuracy: 0.8438 - auc: 0.9912 - recall: 0.9109 - precision: 0.9474
# Epoch 77: val_loss improved from 0.13615 to 0.13531, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1447 - accuracy: 0.8434 - auc: 0.9912 - recall: 0.9107 - precision: 0.9472 - val_loss: 0.1353 - val_accuracy: 0.8384 - val_auc: 0.9918 - val_recall: 0.9130 - val_precision: 0.9598 - lr: 1.3877e-05
# Epoch 78/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.8478 - auc: 0.9913 - recall: 0.9119 - precision: 0.9460
# Epoch 78: val_loss improved from 0.13531 to 0.13489, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1442 - accuracy: 0.8478 - auc: 0.9913 - recall: 0.9119 - precision: 0.9460 - val_loss: 0.1349 - val_accuracy: 0.8351 - val_auc: 0.9918 - val_recall: 0.9127 - val_precision: 0.9592 - lr: 1.3877e-05
# Epoch 79/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1469 - accuracy: 0.8438 - auc: 0.9910 - recall: 0.9085 - precision: 0.9439
# Epoch 79: val_loss did not improve from 0.13489
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1465 - accuracy: 0.8434 - auc: 0.9910 - recall: 0.9082 - precision: 0.9446 - val_loss: 0.1356 - val_accuracy: 0.8362 - val_auc: 0.9918 - val_recall: 0.9110 - val_precision: 0.9566 - lr: 1.3877e-05
# Epoch 80/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1427 - accuracy: 0.8449 - auc: 0.9916 - recall: 0.9112 - precision: 0.9494
# Epoch 80: val_loss improved from 0.13489 to 0.13459, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1432 - accuracy: 0.8442 - auc: 0.9916 - recall: 0.9102 - precision: 0.9487 - val_loss: 0.1346 - val_accuracy: 0.8392 - val_auc: 0.9918 - val_recall: 0.9138 - val_precision: 0.9584 - lr: 1.3877e-05
# Epoch 81/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1418 - accuracy: 0.8439 - auc: 0.9917 - recall: 0.9150 - precision: 0.9466
# Epoch 81: val_loss improved from 0.13459 to 0.13366, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1419 - accuracy: 0.8451 - auc: 0.9916 - recall: 0.9143 - precision: 0.9474 - val_loss: 0.1337 - val_accuracy: 0.8373 - val_auc: 0.9919 - val_recall: 0.9144 - val_precision: 0.9564 - lr: 1.3877e-05
# Epoch 82/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.8442 - auc: 0.9915 - recall: 0.9120 - precision: 0.9463
# Epoch 82: val_loss did not improve from 0.13366
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1431 - accuracy: 0.8442 - auc: 0.9915 - recall: 0.9120 - precision: 0.9463 - val_loss: 0.1339 - val_accuracy: 0.8373 - val_auc: 0.9919 - val_recall: 0.9127 - val_precision: 0.9595 - lr: 1.3877e-05
# Epoch 83/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1431 - accuracy: 0.8454 - auc: 0.9913 - recall: 0.9117 - precision: 0.9457
# Epoch 83: val_loss did not improve from 0.13366
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1433 - accuracy: 0.8445 - auc: 0.9913 - recall: 0.9112 - precision: 0.9462 - val_loss: 0.1338 - val_accuracy: 0.8403 - val_auc: 0.9919 - val_recall: 0.9118 - val_precision: 0.9583 - lr: 1.3877e-05
# Epoch 84/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1418 - accuracy: 0.8476 - auc: 0.9918 - recall: 0.9109 - precision: 0.9510
# Epoch 84: val_loss improved from 0.13366 to 0.13331, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1418 - accuracy: 0.8471 - auc: 0.9918 - recall: 0.9110 - precision: 0.9504 - val_loss: 0.1333 - val_accuracy: 0.8354 - val_auc: 0.9918 - val_recall: 0.9164 - val_precision: 0.9588 - lr: 1.3877e-05
# Epoch 85/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1439 - accuracy: 0.8408 - auc: 0.9913 - recall: 0.9092 - precision: 0.9463
# Epoch 85: val_loss did not improve from 0.13331
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1438 - accuracy: 0.8406 - auc: 0.9913 - recall: 0.9094 - precision: 0.9465 - val_loss: 0.1337 - val_accuracy: 0.8388 - val_auc: 0.9920 - val_recall: 0.9121 - val_precision: 0.9618 - lr: 1.3877e-05
# Epoch 86/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1423 - accuracy: 0.8458 - auc: 0.9915 - recall: 0.9107 - precision: 0.9484
# Epoch 86: val_loss improved from 0.13331 to 0.13208, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1419 - accuracy: 0.8455 - auc: 0.9916 - recall: 0.9115 - precision: 0.9483 - val_loss: 0.1321 - val_accuracy: 0.8403 - val_auc: 0.9920 - val_recall: 0.9170 - val_precision: 0.9585 - lr: 1.3877e-05
# Epoch 87/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1421 - accuracy: 0.8453 - auc: 0.9915 - recall: 0.9125 - precision: 0.9487
# Epoch 87: val_loss improved from 0.13208 to 0.13182, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1425 - accuracy: 0.8445 - auc: 0.9915 - recall: 0.9120 - precision: 0.9484 - val_loss: 0.1318 - val_accuracy: 0.8336 - val_auc: 0.9919 - val_recall: 0.9173 - val_precision: 0.9606 - lr: 1.3877e-05
# Epoch 88/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.8459 - auc: 0.9913 - recall: 0.9114 - precision: 0.9472
# Epoch 88: val_loss did not improve from 0.13182
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1428 - accuracy: 0.8459 - auc: 0.9913 - recall: 0.9114 - precision: 0.9472 - val_loss: 0.1322 - val_accuracy: 0.8369 - val_auc: 0.9920 - val_recall: 0.9150 - val_precision: 0.9579 - lr: 1.3877e-05
# Epoch 89/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.8474 - auc: 0.9915 - recall: 0.9099 - precision: 0.9479
# Epoch 89: val_loss did not improve from 0.13182
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1412 - accuracy: 0.8474 - auc: 0.9915 - recall: 0.9099 - precision: 0.9479 - val_loss: 0.1320 - val_accuracy: 0.8380 - val_auc: 0.9921 - val_recall: 0.9158 - val_precision: 0.9594 - lr: 1.3877e-05
# Epoch 90/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1402 - accuracy: 0.8473 - auc: 0.9918 - recall: 0.9138 - precision: 0.9472
# Epoch 90: val_loss improved from 0.13182 to 0.13087, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1400 - accuracy: 0.8472 - auc: 0.9918 - recall: 0.9140 - precision: 0.9479 - val_loss: 0.1309 - val_accuracy: 0.8362 - val_auc: 0.9922 - val_recall: 0.9150 - val_precision: 0.9590 - lr: 1.3877e-05
# Epoch 91/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1405 - accuracy: 0.8493 - auc: 0.9918 - recall: 0.9119 - precision: 0.9486
# Epoch 91: val_loss did not improve from 0.13087
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1404 - accuracy: 0.8500 - auc: 0.9918 - recall: 0.9117 - precision: 0.9488 - val_loss: 0.1317 - val_accuracy: 0.8440 - val_auc: 0.9921 - val_recall: 0.9141 - val_precision: 0.9599 - lr: 1.3877e-05
# Epoch 92/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1401 - accuracy: 0.8461 - auc: 0.9919 - recall: 0.9109 - precision: 0.9488
# Epoch 92: val_loss did not improve from 0.13087
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1401 - accuracy: 0.8445 - auc: 0.9919 - recall: 0.9108 - precision: 0.9486 - val_loss: 0.1313 - val_accuracy: 0.8392 - val_auc: 0.9923 - val_recall: 0.9113 - val_precision: 0.9612 - lr: 1.3877e-05
# Epoch 93/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1397 - accuracy: 0.8419 - auc: 0.9918 - recall: 0.9108 - precision: 0.9471
# Epoch 93: val_loss improved from 0.13087 to 0.13083, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1400 - accuracy: 0.8426 - auc: 0.9917 - recall: 0.9110 - precision: 0.9470 - val_loss: 0.1308 - val_accuracy: 0.8388 - val_auc: 0.9922 - val_recall: 0.9121 - val_precision: 0.9603 - lr: 1.3877e-05
# Epoch 94/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1390 - accuracy: 0.8434 - auc: 0.9919 - recall: 0.9151 - precision: 0.9477
# Epoch 94: val_loss improved from 0.13083 to 0.12995, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1390 - accuracy: 0.8436 - auc: 0.9919 - recall: 0.9150 - precision: 0.9481 - val_loss: 0.1300 - val_accuracy: 0.8403 - val_auc: 0.9923 - val_recall: 0.9141 - val_precision: 0.9593 - lr: 3.4692e-06
# Epoch 95/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1375 - accuracy: 0.8456 - auc: 0.9921 - recall: 0.9167 - precision: 0.9494
# Epoch 95: val_loss improved from 0.12995 to 0.12964, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1377 - accuracy: 0.8448 - auc: 0.9921 - recall: 0.9164 - precision: 0.9491 - val_loss: 0.1296 - val_accuracy: 0.8399 - val_auc: 0.9923 - val_recall: 0.9150 - val_precision: 0.9587 - lr: 3.4692e-06
# Epoch 96/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1386 - accuracy: 0.8516 - auc: 0.9920 - recall: 0.9136 - precision: 0.9515
# Epoch 96: val_loss did not improve from 0.12964
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1383 - accuracy: 0.8511 - auc: 0.9921 - recall: 0.9138 - precision: 0.9517 - val_loss: 0.1297 - val_accuracy: 0.8418 - val_auc: 0.9922 - val_recall: 0.9153 - val_precision: 0.9573 - lr: 3.4692e-06
# Epoch 97/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1388 - accuracy: 0.8495 - auc: 0.9918 - recall: 0.9115 - precision: 0.9510
# Epoch 97: val_loss did not improve from 0.12964
# ...
# Epoch 168/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1348 - accuracy: 0.8524 - auc: 0.9924 - recall: 0.9192 - precision: 0.9495
# Epoch 168: val_loss did not improve from 0.12752
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1350 - accuracy: 0.8525 - auc: 0.9924 - recall: 0.9190 - precision: 0.9494 - val_loss: 0.1275 - val_accuracy: 0.8395 - val_auc: 0.9924 - val_recall: 0.9147 - val_precision: 0.9582 - lr: 1.0000e-06
# Epoch 169/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1341 - accuracy: 0.8454 - auc: 0.9928 - recall: 0.9196 - precision: 0.9522
# Epoch 169: val_loss did not improve from 0.12752
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1338 - accuracy: 0.8456 - auc: 0.9928 - recall: 0.9195 - precision: 0.9529 - val_loss: 0.1275 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9144 - val_precision: 0.9587 - lr: 1.0000e-06
# Epoch 170/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.8495 - auc: 0.9925 - recall: 0.9168 - precision: 0.9509
# Epoch 170: val_loss improved from 0.12752 to 0.12747, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1345 - accuracy: 0.8496 - auc: 0.9925 - recall: 0.9166 - precision: 0.9509 - val_loss: 0.1275 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9153 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 171/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1354 - accuracy: 0.8438 - auc: 0.9923 - recall: 0.9163 - precision: 0.9510
# Epoch 171: val_loss did not improve from 0.12747
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1358 - accuracy: 0.8442 - auc: 0.9923 - recall: 0.9158 - precision: 0.9504 - val_loss: 0.1275 - val_accuracy: 0.8399 - val_auc: 0.9924 - val_recall: 0.9150 - val_precision: 0.9590 - lr: 1.0000e-06
# Epoch 172/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1353 - accuracy: 0.8501 - auc: 0.9925 - recall: 0.9162 - precision: 0.9508
# Epoch 172: val_loss did not improve from 0.12747
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1350 - accuracy: 0.8495 - auc: 0.9926 - recall: 0.9164 - precision: 0.9516 - val_loss: 0.1275 - val_accuracy: 0.8406 - val_auc: 0.9924 - val_recall: 0.9147 - val_precision: 0.9596 - lr: 1.0000e-06
# Epoch 173/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1360 - accuracy: 0.8477 - auc: 0.9924 - recall: 0.9175 - precision: 0.9500
# Epoch 173: val_loss improved from 0.12747 to 0.12742, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1361 - accuracy: 0.8477 - auc: 0.9924 - recall: 0.9174 - precision: 0.9499 - val_loss: 0.1274 - val_accuracy: 0.8399 - val_auc: 0.9924 - val_recall: 0.9144 - val_precision: 0.9596 - lr: 1.0000e-06
# Epoch 174/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1367 - accuracy: 0.8419 - auc: 0.9921 - recall: 0.9149 - precision: 0.9485
# Epoch 174: val_loss did not improve from 0.12742
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1369 - accuracy: 0.8418 - auc: 0.9921 - recall: 0.9146 - precision: 0.9484 - val_loss: 0.1275 - val_accuracy: 0.8395 - val_auc: 0.9924 - val_recall: 0.9150 - val_precision: 0.9596 - lr: 1.0000e-06
# Epoch 175/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1357 - accuracy: 0.8442 - auc: 0.9923 - recall: 0.9162 - precision: 0.9497
# Epoch 175: val_loss did not improve from 0.12742
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1354 - accuracy: 0.8448 - auc: 0.9924 - recall: 0.9162 - precision: 0.9502 - val_loss: 0.1275 - val_accuracy: 0.8388 - val_auc: 0.9924 - val_recall: 0.9144 - val_precision: 0.9599 - lr: 1.0000e-06
# Epoch 176/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1347 - accuracy: 0.8437 - auc: 0.9925 - recall: 0.9145 - precision: 0.9520
# Epoch 176: val_loss improved from 0.12742 to 0.12735, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1342 - accuracy: 0.8431 - auc: 0.9927 - recall: 0.9147 - precision: 0.9523 - val_loss: 0.1273 - val_accuracy: 0.8388 - val_auc: 0.9924 - val_recall: 0.9161 - val_precision: 0.9591 - lr: 1.0000e-06
# Epoch 177/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.8443 - auc: 0.9922 - recall: 0.9155 - precision: 0.9497
# Epoch 177: val_loss did not improve from 0.12735
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1362 - accuracy: 0.8443 - auc: 0.9922 - recall: 0.9155 - precision: 0.9497 - val_loss: 0.1274 - val_accuracy: 0.8392 - val_auc: 0.9924 - val_recall: 0.9155 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 178/200
# 79/85 [==========================>...] - ETA: 0s - loss: 0.1349 - accuracy: 0.8472 - auc: 0.9924 - recall: 0.9154 - precision: 0.9511
# Epoch 178: val_loss did not improve from 0.12735
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1345 - accuracy: 0.8483 - auc: 0.9924 - recall: 0.9165 - precision: 0.9511 - val_loss: 0.1274 - val_accuracy: 0.8395 - val_auc: 0.9924 - val_recall: 0.9153 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 179/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1352 - accuracy: 0.8428 - auc: 0.9924 - recall: 0.9172 - precision: 0.9482
# Epoch 179: val_loss did not improve from 0.12735
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1351 - accuracy: 0.8427 - auc: 0.9924 - recall: 0.9171 - precision: 0.9483 - val_loss: 0.1274 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9158 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 180/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.8482 - auc: 0.9927 - recall: 0.9174 - precision: 0.9522
# Epoch 180: val_loss improved from 0.12735 to 0.12731, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1347 - accuracy: 0.8482 - auc: 0.9927 - recall: 0.9174 - precision: 0.9522 - val_loss: 0.1273 - val_accuracy: 0.8395 - val_auc: 0.9924 - val_recall: 0.9150 - val_precision: 0.9587 - lr: 1.0000e-06
# Epoch 181/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1361 - accuracy: 0.8460 - auc: 0.9923 - recall: 0.9152 - precision: 0.9498
# Epoch 181: val_loss improved from 0.12731 to 0.12729, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1364 - accuracy: 0.8457 - auc: 0.9923 - recall: 0.9147 - precision: 0.9495 - val_loss: 0.1273 - val_accuracy: 0.8388 - val_auc: 0.9924 - val_recall: 0.9155 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 182/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1355 - accuracy: 0.8487 - auc: 0.9924 - recall: 0.9180 - precision: 0.9502
# Epoch 182: val_loss improved from 0.12729 to 0.12728, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1354 - accuracy: 0.8489 - auc: 0.9925 - recall: 0.9173 - precision: 0.9505 - val_loss: 0.1273 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9150 - val_precision: 0.9593 - lr: 1.0000e-06
# Epoch 183/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1339 - accuracy: 0.8479 - auc: 0.9928 - recall: 0.9174 - precision: 0.9494
# Epoch 183: val_loss did not improve from 0.12728
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1344 - accuracy: 0.8470 - auc: 0.9928 - recall: 0.9169 - precision: 0.9492 - val_loss: 0.1273 - val_accuracy: 0.8395 - val_auc: 0.9924 - val_recall: 0.9147 - val_precision: 0.9599 - lr: 1.0000e-06
# Epoch 184/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.8455 - auc: 0.9927 - recall: 0.9187 - precision: 0.9508
# Epoch 184: val_loss did not improve from 0.12728
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1353 - accuracy: 0.8455 - auc: 0.9927 - recall: 0.9186 - precision: 0.9507 - val_loss: 0.1273 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9155 - val_precision: 0.9593 - lr: 1.0000e-06
# Epoch 185/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1352 - accuracy: 0.8459 - auc: 0.9925 - recall: 0.9164 - precision: 0.9516
# Epoch 185: val_loss improved from 0.12728 to 0.12722, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1349 - accuracy: 0.8472 - auc: 0.9925 - recall: 0.9171 - precision: 0.9515 - val_loss: 0.1272 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9147 - val_precision: 0.9587 - lr: 1.0000e-06
# Epoch 186/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1328 - accuracy: 0.8470 - auc: 0.9930 - recall: 0.9196 - precision: 0.9509
# Epoch 186: val_loss improved from 0.12722 to 0.12719, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1325 - accuracy: 0.8477 - auc: 0.9930 - recall: 0.9198 - precision: 0.9507 - val_loss: 0.1272 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9147 - val_precision: 0.9593 - lr: 1.0000e-06
# Epoch 187/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1354 - accuracy: 0.8456 - auc: 0.9924 - recall: 0.9171 - precision: 0.9482
# Epoch 187: val_loss improved from 0.12719 to 0.12710, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1350 - accuracy: 0.8455 - auc: 0.9925 - recall: 0.9176 - precision: 0.9489 - val_loss: 0.1271 - val_accuracy: 0.8406 - val_auc: 0.9924 - val_recall: 0.9155 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 188/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1342 - accuracy: 0.8465 - auc: 0.9924 - recall: 0.9197 - precision: 0.9518
# Epoch 188: val_loss improved from 0.12710 to 0.12706, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1344 - accuracy: 0.8467 - auc: 0.9924 - recall: 0.9195 - precision: 0.9517 - val_loss: 0.1271 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9158 - val_precision: 0.9591 - lr: 1.0000e-06
# Epoch 189/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1354 - accuracy: 0.8449 - auc: 0.9924 - recall: 0.9135 - precision: 0.9508
# Epoch 189: val_loss did not improve from 0.12706
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1356 - accuracy: 0.8454 - auc: 0.9923 - recall: 0.9140 - precision: 0.9498 - val_loss: 0.1271 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9161 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 190/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1354 - accuracy: 0.8464 - auc: 0.9923 - recall: 0.9175 - precision: 0.9504
# Epoch 190: val_loss did not improve from 0.12706
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1355 - accuracy: 0.8467 - auc: 0.9923 - recall: 0.9174 - precision: 0.9500 - val_loss: 0.1271 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9158 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 191/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1354 - accuracy: 0.8460 - auc: 0.9923 - recall: 0.9157 - precision: 0.9529
# Epoch 191: val_loss did not improve from 0.12706
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1353 - accuracy: 0.8460 - auc: 0.9923 - recall: 0.9158 - precision: 0.9528 - val_loss: 0.1271 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9155 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 192/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.8471 - auc: 0.9928 - recall: 0.9125 - precision: 0.9519
# Epoch 192: val_loss improved from 0.12706 to 0.12704, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1350 - accuracy: 0.8471 - auc: 0.9928 - recall: 0.9125 - precision: 0.9519 - val_loss: 0.1270 - val_accuracy: 0.8384 - val_auc: 0.9924 - val_recall: 0.9153 - val_precision: 0.9593 - lr: 1.0000e-06
# Epoch 193/200
# 80/85 [===========================>..] - ETA: 0s - loss: 0.1357 - accuracy: 0.8473 - auc: 0.9923 - recall: 0.9162 - precision: 0.9483
# Epoch 193: val_loss did not improve from 0.12704
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1362 - accuracy: 0.8459 - auc: 0.9923 - recall: 0.9159 - precision: 0.9479 - val_loss: 0.1271 - val_accuracy: 0.8399 - val_auc: 0.9924 - val_recall: 0.9158 - val_precision: 0.9594 - lr: 1.0000e-06
# Epoch 194/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1359 - accuracy: 0.8449 - auc: 0.9922 - recall: 0.9156 - precision: 0.9495
# Epoch 194: val_loss improved from 0.12704 to 0.12694, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1355 - accuracy: 0.8452 - auc: 0.9923 - recall: 0.9161 - precision: 0.9500 - val_loss: 0.1269 - val_accuracy: 0.8399 - val_auc: 0.9924 - val_recall: 0.9158 - val_precision: 0.9594 - lr: 1.0000e-06
# Epoch 195/200
# 81/85 [===========================>..] - ETA: 0s - loss: 0.1352 - accuracy: 0.8485 - auc: 0.9924 - recall: 0.9149 - precision: 0.9493
# Epoch 195: val_loss improved from 0.12694 to 0.12683, saving model to ../models\best_bayesian_model.h5
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1351 - accuracy: 0.8481 - auc: 0.9924 - recall: 0.9152 - precision: 0.9496 - val_loss: 0.1268 - val_accuracy: 0.8395 - val_auc: 0.9924 - val_recall: 0.9155 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 196/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1346 - accuracy: 0.8461 - auc: 0.9924 - recall: 0.9176 - precision: 0.9520
# Epoch 196: val_loss did not improve from 0.12683
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1346 - accuracy: 0.8458 - auc: 0.9924 - recall: 0.9176 - precision: 0.9520 - val_loss: 0.1269 - val_accuracy: 0.8399 - val_auc: 0.9924 - val_recall: 0.9158 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 197/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.8480 - auc: 0.9927 - recall: 0.9179 - precision: 0.9516
# Epoch 197: val_loss did not improve from 0.12683
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1332 - accuracy: 0.8480 - auc: 0.9927 - recall: 0.9179 - precision: 0.9516 - val_loss: 0.1269 - val_accuracy: 0.8403 - val_auc: 0.9924 - val_recall: 0.9164 - val_precision: 0.9588 - lr: 1.0000e-06
# Epoch 198/200
# 84/85 [============================>.] - ETA: 0s - loss: 0.1344 - accuracy: 0.8515 - auc: 0.9925 - recall: 0.9158 - precision: 0.9519
# Epoch 198: val_loss did not improve from 0.12683
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1344 - accuracy: 0.8514 - auc: 0.9926 - recall: 0.9159 - precision: 0.9520 - val_loss: 0.1269 - val_accuracy: 0.8406 - val_auc: 0.9924 - val_recall: 0.9161 - val_precision: 0.9591 - lr: 1.0000e-06
# Epoch 199/200
# 83/85 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.8454 - auc: 0.9929 - recall: 0.9206 - precision: 0.9532
# Epoch 199: val_loss did not improve from 0.12683
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1327 - accuracy: 0.8454 - auc: 0.9929 - recall: 0.9204 - precision: 0.9528 - val_loss: 0.1269 - val_accuracy: 0.8399 - val_auc: 0.9924 - val_recall: 0.9164 - val_precision: 0.9594 - lr: 1.0000e-06
# Epoch 200/200
# 82/85 [===========================>..] - ETA: 0s - loss: 0.1380 - accuracy: 0.8444 - auc: 0.9920 - recall: 0.9138 - precision: 0.9490
# Epoch 200: val_loss did not improve from 0.12683
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1377 - accuracy: 0.8450 - auc: 0.9920 - recall: 0.9135 - precision: 0.9495 - val_loss: 0.1268 - val_accuracy: 0.8399 - val_auc: 0.9925 - val_recall: 0.9158 - val_precision: 0.9594 - lr: 1.0000e-06

# %% [markdown]
# ## Plotting the training results

# %%
# Define the metrics to plot
metrics = ['accuracy', 'auc', 'recall', 'precision']

# Create subplots for each metric
plt.figure(figsize=(8, 6))
for i, metric in enumerate(metrics):
    plt.subplot(2, 2, i + 1)  # Create a 2x2 grid of plots
    plt.plot(history.history[metric], label=f'Training {metric.capitalize()}')
    plt.plot(history.history[f'val_{metric}'], label=f'Validation {metric.capitalize()}')
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()
    plt.title(f'Training vs Validation {metric.capitalize()}')
    
plt.tight_layout()
plt.show()

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')
plt.show()

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')
plt.show()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Validation Loss')
plt.show()

# %%
# Plot training and validation accuracy
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.title('Training vs Validation AUC')
plt.show()

# %%
# Plot training and validation accuracy
plt.plot(history.history['recall'], label='Training Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.title('Training vs Validation Recall')
plt.show()

# %%
# Plot training and validation accuracy
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.title('Training vs Validation Precision')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('../models/best_model.h5')

# %% [markdown]
# ## Visualizing  And Evaluating The Model Performance For Each Class

# %%
from sklearn.metrics import multilabel_confusion_matrix, classification_report

# Generate predictions
y_pred_proba = model.predict({"embedding_input": X_emb_val, "additional_input": X_add_val})
y_pred = (y_pred_proba > 0.5).astype(int)

# Multilabel confusion matrix
conf_matrices = multilabel_confusion_matrix(y_val, y_pred)

# Display classification report
print(classification_report(y_val, y_pred, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4', 'Class 5']))
# Out:
# 85/85 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#      Class 1       0.97      0.96      0.96       853
#      Class 2       0.98      0.96      0.97      1044
#      Class 3       0.95      0.93      0.94       730
#      Class 4       0.98      0.94      0.96       334
#      Class 5       0.97      0.93      0.95       544
#
#    micro avg       0.97      0.95      0.96      3505
#    macro avg       0.97      0.94      0.96      3505
# weighted avg       0.97      0.95      0.96      3505
#  samples avg       0.97      0.96      0.96      3505
# c:\Users\dighz\anaconda3\envs\ford_case_iel\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# After evaluating the F1-score, recall and precision metrics we can see that it is not favoring larger categories in a significant way.
#
# Therefore, it is not necessary to apply balancing techniques.

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Binarize the output (for multi-label ROC)
y_test_bin = label_binarize(y_val, classes=[0, 1, 2, 3, 4])
n_classes = y_test_bin.shape[1]

# Compute ROC curve and AUC for each class
fpr, tpr, roc_auc = {}, {}, {}
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    print(roc_auc[i])

# Plot all ROC curves
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i+1} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Multi-Label Classification')
plt.legend(loc='lower right')
plt.show()
# Out:
# 0.9923393556439959
# 0.9927475077186325
# 0.9905547875385753
# 0.9893990644664868
# 0.992700973545843
